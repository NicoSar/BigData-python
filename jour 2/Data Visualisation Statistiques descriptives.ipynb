# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/house_pricing.csv')
print('data loaded')
# Out:
# data loaded

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.columns.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
sns.relplot(x='LotArea', y='SalePrice', data=df)

# %%
sns.relplot(x='LotArea', y='SalePrice', data=df[(df['LotArea']< 20000) & (df['SalePrice']< 500000) ])

# %%
sns.relplot(x='LotFrontage', y='LotArea', data=df)

# %%
sns.relplot(x='LotFrontage', y='LotArea', data=df[(df['LotFrontage']< 200) & (df['LotArea']< 100000) ] )

# %%
df = pd.read_csv('data/sales_predictions.csv')
print('data loaded')
# Out:
# data loaded

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
mindate = df['date'].min() 
mindate
# Out:
# '01.01.2013'

# %%
maxdate = df['date'].max() 
maxdate
# Out:
# '31.12.2014'

# %%
sns.relplot(x='date', y='item_price' , data=df)

# %%
sns.relplot(x='date', y='item_price' , data=df.sample(n=50))

# %%
f, axes = plt.subplots(1,sharey=True,figsize=(20, 6))
sns.scatterplot(x='date', y='item_price', data=df.sample(n=50), ax=axes)

# %%
pd.to_datetime(df['date']).sample(n=50)
# Out:
# 2674788   2015-06-27
# 1600165   2014-12-04
# 1499603   2014-03-15
# 650978    2013-08-07
# 452061    2013-05-22
# 1907462   2014-08-30
# 1752233   2014-06-24
# 669275    2013-07-16
# 198284    2013-09-02
# 338631    2013-03-30
# 2807209   2015-08-27
# 2238926   2014-12-16
# 1578451   2014-09-04
# 1741962   2014-12-06
# 1841164   2014-07-28
# 145024    2013-02-13
# 2777269   2015-05-08
# 523457    2013-02-05
# 1627909   2014-05-15
# 2493075   2015-03-03
# 52376     2013-01-13
# 1314880   2014-02-01
# 2261971   2014-12-17
# 1838888   2014-07-16
# 943563    2013-10-31
# 2133832   2014-11-17
# 1448572   2014-02-15
# 462060    2013-05-24
# 564841    2013-06-15
# 1472730   2014-12-03
# 1699938   2014-11-05
# 802020    2013-06-08
# 1784216   2014-06-22
# 1451553   2014-02-20
# 1975043   2014-03-09
# 2182261   2014-02-11
# 480821    2013-05-26
# 2841851   2015-09-26
# 1683836   2014-05-26
# 804920    2013-08-14
# 1442041   2014-02-23
# 147914    2013-10-02
# 1464354   2014-03-25
# ...

# %%
pd.to_datetime(df['date'])
# Out:
# 0         2013-02-01
# 1         2013-03-01
# 2         2013-05-01
# 3         2013-06-01
# 4         2013-01-15
#              ...
# 2935844   2015-10-10
# 2935845   2015-09-10
# 2935846   2015-10-14
# 2935847   2015-10-22
# 2935848   2015-03-10
# Name: date, Length: 2935849, dtype: datetime64[ns]

# %%
f, axes = plt.subplots(1,sharey=True,figsize=(20, 6))
setX = pd.to_datetime(df['date'])
sns.scatterplot(x=setX, y='item_price', data=df.sample(n=50), ax=axes)

# %%
df['date'] = pd.to_datetime(df['date'])
graph = sns.relplot(x='date', y='item_price', data=df.sample(n=50))
graph.fig.set_figwidth(20)
graph.fig.set_figheight(6)

# %%
df = pd.read_csv('data/IBM_HR_ATTRITION.csv')
print('data loaded')
# Out:
# data loaded

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
sns.catplot(x="Attrition",y="JobSatisfaction",kind="bar",data=df)

# %%
sns.boxplot(x="Attrition",y="JobSatisfaction",data=df)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
sns.boxplot(x='Attrition', y='TotalWorkingYears', data=df)

# %%
df2 = df
df2.Attrition = df2.Attrition.replace(to_replace=['Yes','No'],value=[1,0])
sns.catplot(x='EducationField', y='Attrition', hue="Department", data=df2, kind="bar")

# %%
df = pd.read_csv('data/IBM_HR_ATTRITION.csv')
print('data loaded')
# Out:
# data loaded

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sns.distplot(df.MonthlyIncome)

# %%
sns.distplot(df.query('MonthlyIncome > 0 & MonthlyIncome < 5000')['MonthlyIncome'])

# %%
df = pd.read_csv('data/IBM_HR_ATTRITION.csv')
print('data loaded')
# Out:
# data loaded

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.Attrition = df.Attrition.replace(to_replace=['Yes','No'],value=[1,0])
sns.lmplot(x='DistanceFromHome', y='Attrition', data=df)

# %%
sns.lmplot(x='YearsWithCurrManager', y='Attrition', data=df)

# %%
df = pd.read_csv('data/house_pricing.csv')
print('data loaded')
# Out:
# data loaded

# %%
plt.subplots(figsize=(20,15))
heatmap = sns.heatmap(df[(df.columns[-15:])].corr(), annot=True)
